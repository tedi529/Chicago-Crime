# %%
# Import Dependencies
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Import and Check Chicago Crime Datasets

# %%
# Import 2016 crime data
crime_2016 = os.path.join("Resources", "crime_clean_2016.csv") 

crime_2016_df_final = pd.read_csv(crime_2016, index_col='id')

crime_2016_df_final.head()
# Out:
#                              date  day  month  year          time  hour  \
# id
# 10819224  2016-12-31T23:59:00.000   31     12  2016  23:59:00.000    23
# 10801137  2016-12-31T23:58:00.000   31     12  2016  23:58:00.000    23
# 10801110  2016-12-31T23:55:00.000   31     12  2016  23:55:00.000    23
# 10802006  2016-12-31T23:55:00.000   31     12  2016  23:55:00.000    23
# 10801865  2016-12-31T23:54:00.000   31     12  2016  23:54:00.000    23
#
#           month_day  day_of_week  district                block  ...  \
# id                                                               ...
# 10819224       1231            5        16     100XX W OHARE ST  ...
# 10801137       1231            5         5     0000X W 113TH PL  ...
# 10801110       1231            5        19  030XX N LINCOLN AVE  ...
# 10802006       1231            5         1    0000X E WACKER PL  ...
# 10801865       1231            5         6  078XX S INDIANA AVE  ...
#
# ...

# %%
# Import 2017 crime data
crime_2017 = os.path.join("Resources", "crime_clean_2017.csv") 

crime_2017_df_final = pd.read_csv(crime_2017, index_col='id')

crime_2017_df_final.head()
# Out:
#                              date  day  month  year          time  hour  \
# id
# 11192233  2017-12-31T23:58:00.000   31     12  2017  23:58:00.000    23
# 11196379  2017-12-31T23:50:00.000   31     12  2017  23:50:00.000    23
# 11192540  2017-12-31T23:48:00.000   31     12  2017  23:48:00.000    23
# 11192254  2017-12-31T23:45:00.000   31     12  2017  23:45:00.000    23
# 11192239  2017-12-31T23:45:00.000   31     12  2017  23:45:00.000    23
#
#           month_day  day_of_week  district                     block  ...  \
# id                                                                    ...
# 11192233       1231            6        17      046XX N ST LOUIS AVE  ...
# 11196379       1231            6        19  024XX N LAKE SHORE DR NB  ...
# 11192540       1231            6        18       001XX E SUPERIOR ST  ...
# 11192254       1231            6         5          115XX S STATE ST  ...
# 11192239       1231            6        12          019XX S CANAL ST  ...
#
# ...

# %%
# Import 2018 crime data
crime_2018 = os.path.join("Resources", "crime_clean_2018.csv") 

crime_2018_df_final = pd.read_csv(crime_2018, index_col='id')

crime_2018_df_final.head()
# Out:
#                              date  day  month  year          time  hour  \
# id
# 11556487  2018-12-31T23:59:00.000   31     12  2018  23:59:00.000    23
# 11552699  2018-12-31T23:57:00.000   31     12  2018  23:57:00.000    23
# 11552724  2018-12-31T23:56:00.000   31     12  2018  23:56:00.000    23
# 11552731  2018-12-31T23:55:00.000   31     12  2018  23:55:00.000    23
# 11552715  2018-12-31T23:49:00.000   31     12  2018  23:49:00.000    23
#
#           month_day  day_of_week  district                   block  ...  \
# id                                                                  ...
# 11556487       1231            0        22  112XX S SACRAMENTO AVE  ...
# 11552699       1231            0         6     084XX S SANGAMON ST  ...
# 11552724       1231            0        12      018XX S ALLPORT ST  ...
# 11552731       1231            0         6     078XX S SANGAMON ST  ...
# 11552715       1231            0        15      052XX W GLADYS AVE  ...
#
# ...

# %%
# Check if columns in dataframes are identical 
if crime_2016_df_final.columns.all() == crime_2017_df_final.columns.all() == crime_2018_df_final.columns.all():
    print("Columns are identical")
else:
    print("Columns are not identical")
# Out:
# Columns are identical

# %%
# Join datasets for 2016, 2017, and 2018
join1 = crime_2016_df_final.append(crime_2017_df_final)
training_df = join1.append(crime_2018_df_final)
training_df
# Out:
#                              date  day  month  year          time  hour  \
# id
# 10819224  2016-12-31T23:59:00.000   31     12  2016  23:59:00.000    23
# 10801137  2016-12-31T23:58:00.000   31     12  2016  23:58:00.000    23
# 10801110  2016-12-31T23:55:00.000   31     12  2016  23:55:00.000    23
# 10802006  2016-12-31T23:55:00.000   31     12  2016  23:55:00.000    23
# 10801865  2016-12-31T23:54:00.000   31     12  2016  23:54:00.000    23
# ...                           ...  ...    ...   ...           ...   ...
# 11459757  2018-01-01T00:00:00.000    1      1  2018  00:00:00.000     0
# 11315895  2018-01-01T00:00:00.000    1      1  2018  00:00:00.000     0
# 11196173  2018-01-01T00:00:00.000    1      1  2018  00:00:00.000     0
# 11533503  2018-01-01T00:00:00.000    1      1  2018  00:00:00.000     0
# 11479066  2018-01-01T00:00:00.000    1      1  2018  00:00:00.000     0
#
#           month_day  day_of_week  district                   block  ...  \
# ...

# %%
# Check sum of lengths of individual datasets match combined length
length1 = len(crime_2016_df_final) + len(crime_2017_df_final) + len(crime_2018_df_final)
if length1 == len(training_df):
    print("Same length")
else: 
    print("Different length")
# Out:
# Same length

# %%
# Import 2019 crime data and prepare for testing
crime_2019 = os.path.join("Resources", "crime_clean_2019.csv") 

crime_2019_df_final = pd.read_csv(crime_2019, index_col='id')

crime_2019_df_final.head()
# Out:
#                              date  day  month  year          time  hour  \
# id
# 11938228  2019-12-31T23:55:00.000   31     12  2019  23:55:00.000    23
# 11940078  2019-12-31T23:54:00.000   31     12  2019  23:54:00.000    23
# 11938240  2019-12-31T23:48:00.000   31     12  2019  23:48:00.000    23
# 11937967  2019-12-31T23:46:00.000   31     12  2019  23:46:00.000    23
# 11938124  2019-12-31T23:37:00.000   31     12  2019  23:37:00.000    23
#
#           month_day  day_of_week  district                 block  ...  \
# id                                                                ...
# 11938228       1231            1         7       0000X W 69TH ST  ...
# 11940078       1231            1         7        063XX S MAY ST  ...
# 11938240       1231            1        15    004XX S CICERO AVE  ...
# 11937967       1231            1        11  034XX W JACKSON BLVD  ...
# 11938124       1231            1        22       012XX W 99TH ST  ...
#
# ...
