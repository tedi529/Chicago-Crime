# %% [markdown]
# # SGD Classifier with Ensemble Methods: Bootstrap Aggregation

# %%
# Import Dependencies
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import os

# %%
# Import 2018 crime data
crime_2018 = os.path.join("..","Resources", "crime_clean_2018.csv") 
crime_2018_data = pd.read_csv(crime_2018, index_col="id")

# %%
# Process data to get desired format
training_2018 = crime_2018_data.drop(columns=["date", "day", "year", "time", "month_day", "district", "block", "ward", "beat",
                                              "community_area", "description","iucr", "x_coordinate", "y_coordinate", "fbi_code", 
                                              "domestic", "latitude", "longitude"], axis=1)
# Out:
#           month  hour  day_of_week location_description     primary_type  \
# id
# 11556487     12    23            0               STREET  CRIMINAL DAMAGE
# 11552699     12    23            0            APARTMENT  CRIMINAL DAMAGE
# 11552724     12    23            0                OTHER          BATTERY
# 11552731     12    23            0            APARTMENT          BATTERY
# 11552715     12    23            0               STREET          BATTERY
#
#           arrest
# id
# 11556487   False
# 11552699   False
# 11552724    True
# 11552731   False
# 11552715   False

# %%
# Label encode categorical features
from sklearn.preprocessing import LabelEncoder

# Choose categorical features
objects_training_data_2018 = training_2018[["location_description", "primary_type", "arrest"]]
numerical_training_data_2018 = training_2018[["month", "hour", "day_of_week"]]

# Encode categorical features
cat_objects_training_data_2018 = objects_training_data_2018.apply(LabelEncoder().fit_transform)
cat_objects_training_data_2018
# Out:
#           location_description  primary_type  arrest
# id
# 11556487                   129             6       0
# 11552699                    17             6       0
# 11552724                    96             2       1
# 11552731                    17             2       0
# 11552715                   129             2       0
# ...                        ...           ...     ...
# 11459757                   108            22       0
# 11315895                   108             9       0
# 11196173                   108             9       0
# 11533503                   108            29       0
# 11479066                   108            24       0
#
# [260105 rows x 3 columns]

# %%
# One hot encode features
encoded_object_2018_df = pd.get_dummies(cat_objects_training_data_2018, columns=["location_description", "primary_type"])
encoded_object_2018_df2 = pd.get_dummies(numerical_training_data_2018, columns=["month", "hour", "day_of_week"])

# %%
# Join encoded categorical and numerical dataframes
training_data_2018_final = encoded_object_2018_df.join(encoded_object_2018_df2)
training_data_2018_final
# Out:
#           arrest  location_description_0  location_description_1  \
# id
# 11556487       0                       0                       0
# 11552699       0                       0                       0
# 11552724       1                       0                       0
# 11552731       0                       0                       0
# 11552715       0                       0                       0
# ...          ...                     ...                     ...
# 11459757       0                       0                       0
# 11315895       0                       0                       0
# 11196173       0                       0                       0
# 11533503       0                       0                       0
# 11479066       0                       0                       0
#
#           location_description_2  location_description_3  \
# id
# 11556487                       0                       0
# 11552699                       0                       0
# 11552724                       0                       0
# 11552731                       0                       0
# 11552715                       0                       0
# ...                          ...                     ...
# 11459757                       0                       0
# 11315895                       0                       0
# 11196173                       0                       0
# 11533503                       0                       0
# 11479066                       0                       0
#
#           location_description_4  location_description_5  \
# id
# 11556487                       0                       0
# 11552699                       0                       0
# 11552724                       0                       0
# 11552731                       0                       0
# 11552715                       0                       0
# ...                          ...                     ...
# 11459757                       0                       0
# 11315895                       0                       0
# 11196173                       0                       0
# 11533503                       0                       0
# 11479066                       0                       0
#
#           location_description_6  location_description_7  \
# id
# 11556487                       0                       0
# 11552699                       0                       0
# 11552724                       0                       0
# 11552731                       0                       0
# 11552715                       0                       0
# ...                          ...                     ...
# 11459757                       0                       0
# 11315895                       0                       0
# 11196173                       0                       0
# 11533503                       0                       0
# 11479066                       0                       0
#
#           location_description_8  ...  hour_21  hour_22  hour_23  \
# id                                ...
# 11556487                       0  ...        0        0        1
# 11552699                       0  ...        0        0        1
# 11552724                       0  ...        0        0        1
# 11552731                       0  ...        0        0        1
# 11552715                       0  ...        0        0        1
# ...                          ...  ...      ...      ...      ...
# 11459757                       0  ...        0        0        0
# 11315895                       0  ...        0        0        0
# 11196173                       0  ...        0        0        0
# 11533503                       0  ...        0        0        0
# 11479066                       0  ...        0        0        0
#
#           day_of_week_0  day_of_week_1  day_of_week_2  day_of_week_3  \
# id
# 11556487              1              0              0              0
# 11552699              1              0              0              0
# 11552724              1              0              0              0
# 11552731              1              0              0              0
# 11552715              1              0              0              0
# ...                 ...            ...            ...            ...
# 11459757              1              0              0              0
# 11315895              1              0              0              0
# 11196173              1              0              0              0
# 11533503              1              0              0              0
# 11479066              1              0              0              0
#
#           day_of_week_4  day_of_week_5  day_of_week_6
# id
# 11556487              0              0              0
# 11552699              0              0              0
# 11552724              0              0              0
# 11552731              0              0              0
# 11552715              0              0              0
# ...                 ...            ...            ...
# 11459757              0              0              0
# 11315895              0              0              0
# 11196173              0              0              0
# 11533503              0              0              0
# 11479066              0              0              0
#
# [260105 rows x 224 columns]

# %% [markdown]
# ### Import testing data

# %%
# Import 2019 crime data and prepare for testing
crime_2019 = os.path.join("..","Resources", "crime_clean_2019.csv") 
crime_2019_data = pd.read_csv(crime_2019, index_col='id')

# %%
# Drop columns that will not be used as features / reflecting process during model building
crime_2019_df = crime_2019_data.drop(columns=["date", "day", "year", "time", "month_day", "district", "block", "ward", "beat",
                                              "community_area", "description","iucr", "x_coordinate", "y_coordinate", "fbi_code", 
                                              "domestic", "latitude", "longitude"], axis=1)

# %%
# Choose categorical features
objects_training_data_2019 = crime_2019_df[["location_description", "primary_type", "arrest"]]
numerical_training_data_2019 = crime_2019_df[["month", "hour", "day_of_week"]]

# Encode categorical features
cat_objects_training_data_2019 = objects_training_data_2019.apply(LabelEncoder().fit_transform)

# %%
# One hot encode features
encoded_object_2019_df = pd.get_dummies(cat_objects_training_data_2019, columns=["location_description", "primary_type"])
encoded_object_2019_df2 = pd.get_dummies(numerical_training_data_2019, columns=["month", "hour", "day_of_week"])

# %%
# Join encoded categorical and numerical dataframes in the testing data
crime_2019_final = encoded_object_2019_df.join(encoded_object_2019_df2)

crime_2019_final.head()
# Out:
#           arrest  location_description_0  location_description_1  \
# id
# 11938228       1                       0                       0
# 11940078       0                       0                       0
# 11938240       1                       0                       0
# 11937967       0                       0                       0
# 11938124       1                       0                       0
#
#           location_description_2  location_description_3  \
# id
# 11938228                       0                       0
# 11940078                       0                       0
# 11938240                       0                       0
# 11937967                       0                       0
# 11938124                       0                       0
#
#           location_description_4  location_description_5  \
# id
# 11938228                       0                       0
# 11940078                       0                       0
# 11938240                       0                       0
# 11937967                       0                       0
# 11938124                       0                       0
#
#           location_description_6  location_description_7  \
# id
# 11938228                       0                       0
# 11940078                       0                       0
# 11938240                       0                       0
# 11937967                       0                       0
# 11938124                       0                       0
#
#           location_description_8  ...  hour_21  hour_22  hour_23  \
# id                                ...
# 11938228                       0  ...        0        0        1
# 11940078                       0  ...        0        0        1
# 11938240                       0  ...        0        0        1
# 11937967                       0  ...        0        0        1
# 11938124                       0  ...        0        0        1
#
#           day_of_week_0  day_of_week_1  day_of_week_2  day_of_week_3  \
# id
# 11938228              0              1              0              0
# 11940078              0              1              0              0
# 11938240              0              1              0              0
# 11937967              0              1              0              0
# 11938124              0              1              0              0
#
#           day_of_week_4  day_of_week_5  day_of_week_6
# id
# 11938228              0              0              0
# 11940078              0              0              0
# 11938240              0              0              0
# 11937967              0              0              0
# 11938124              0              0              0
#
# [5 rows x 228 columns]

# %% [markdown]
# ### Standardize Training and Testing Data

# %%
# Keep only columns in testing data that also exist in training data
training_data_2018_final = training_data_2018_final.drop(['primary_type_32'], axis=1)
training_data_cols = training_data_2018_final.columns.values
testing_data_final = crime_2019_final[training_data_cols]
testing_data_final
# Out:
#           arrest  location_description_0  location_description_1  \
# id
# 11938228       1                       0                       0
# 11940078       0                       0                       0
# 11938240       1                       0                       0
# 11937967       0                       0                       0
# 11938124       1                       0                       0
# ...          ...                     ...                     ...
# 11951364       0                       0                       0
# 11937662       0                       0                       0
# 11556297       0                       0                       0
# 11752915       0                       0                       0
# 11742862       0                       0                       0
#
#           location_description_2  location_description_3  \
# id
# 11938228                       0                       0
# 11940078                       0                       0
# 11938240                       0                       0
# 11937967                       0                       0
# 11938124                       0                       0
# ...                          ...                     ...
# 11951364                       0                       0
# 11937662                       0                       0
# 11556297                       0                       0
# 11752915                       0                       0
# 11742862                       0                       0
#
#           location_description_4  location_description_5  \
# id
# 11938228                       0                       0
# 11940078                       0                       0
# 11938240                       0                       0
# 11937967                       0                       0
# 11938124                       0                       0
# ...                          ...                     ...
# 11951364                       0                       0
# 11937662                       0                       0
# 11556297                       0                       0
# 11752915                       0                       0
# 11742862                       0                       0
#
#           location_description_6  location_description_7  \
# id
# 11938228                       0                       0
# 11940078                       0                       0
# 11938240                       0                       0
# 11937967                       0                       0
# 11938124                       0                       0
# ...                          ...                     ...
# 11951364                       0                       0
# 11937662                       0                       0
# 11556297                       0                       0
# 11752915                       0                       0
# 11742862                       0                       0
#
#           location_description_8  ...  hour_21  hour_22  hour_23  \
# id                                ...
# 11938228                       0  ...        0        0        1
# 11940078                       0  ...        0        0        1
# 11938240                       0  ...        0        0        1
# 11937967                       0  ...        0        0        1
# 11938124                       0  ...        0        0        1
# ...                          ...  ...      ...      ...      ...
# 11951364                       0  ...        0        0        0
# 11937662                       0  ...        0        0        0
# 11556297                       0  ...        0        0        0
# 11752915                       0  ...        0        0        0
# 11742862                       0  ...        0        0        0
#
#           day_of_week_0  day_of_week_1  day_of_week_2  day_of_week_3  \
# id
# 11938228              0              1              0              0
# 11940078              0              1              0              0
# 11938240              0              1              0              0
# 11937967              0              1              0              0
# 11938124              0              1              0              0
# ...                 ...            ...            ...            ...
# 11951364              0              1              0              0
# 11937662              0              1              0              0
# 11556297              0              1              0              0
# 11752915              0              1              0              0
# 11742862              0              1              0              0
#
#           day_of_week_4  day_of_week_5  day_of_week_6
# id
# 11938228              0              0              0
# 11940078              0              0              0
# 11938240              0              0              0
# 11937967              0              0              0
# 11938124              0              0              0
# ...                 ...            ...            ...
# 11951364              0              0              0
# 11937662              0              0              0
# 11556297              0              0              0
# 11752915              0              0              0
# 11742862              0              0              0
#
# [256908 rows x 223 columns]

# %%
# Assert training and testing data equal (if no output, then equal)
np.testing.assert_array_equal(testing_data_final.columns.values, training_data_2018_final.columns.values)

# %% [markdown]
# ## Data Exploration

# %%
# Determine which features to keep

# Separate data by arrest (1) and no arrest (0)
Arrest_1_df = training_data_2018_final.loc[training_data_2018_final["arrest"] == 1]
Arrest_0_df = training_data_2018_final.loc[training_data_2018_final["arrest"] == 0]

# Find means for each feature in both datasets
Arrest_1_mean = Arrest_1_df.mean()
Arrest_0_mean = Arrest_0_df.mean()

# Calculate normalized differences of the features for the two datasets
# Values that differ most between two datasets are more likely to be useful as a differentiator between the two classes 
differences = (Arrest_1_mean.subtract(Arrest_0_mean))
normalized_diffs = differences.abs().sort_values()

pd.set_option("max_rows", None)
df = pd.DataFrame(normalized_diffs)
df
# Out:
#                                      0
# location_description_119  1.063464e-07
# location_description_135  4.811092e-06
# primary_type_23           4.811092e-06
# location_description_58   4.811092e-06
# location_description_70   4.811092e-06
# location_description_85   4.811092e-06
# location_description_93   4.811092e-06
# location_description_89   4.811092e-06
# location_description_133  4.811092e-06
# location_description_138  4.811092e-06
# location_description_120  4.811092e-06
# location_description_142  4.917439e-06
# location_description_12   4.917439e-06
# location_description_48   6.461625e-06
# location_description_91   8.107831e-06
# location_description_27   8.877760e-06
# location_description_141  9.409492e-06
# primary_type_20           9.515839e-06
# location_description_37   9.622185e-06
# location_description_62   9.622185e-06
# location_description_68   9.622185e-06
# location_description_109  9.728531e-06
# location_description_118  1.400789e-05
# location_description_132  1.422058e-05
# location_description_111  1.422058e-05
# location_description_128  1.432693e-05
# location_description_76   1.432693e-05
# location_description_66   1.432693e-05
# location_description_33   1.443328e-05
# location_description_81   1.453962e-05
# location_description_35   1.913802e-05
# location_description_117  1.913802e-05
# location_description_25   1.913802e-05
# location_description_88   1.913802e-05
# location_description_51   1.913802e-05
# location_description_95   1.913802e-05
# location_description_146  1.913802e-05
# location_description_116  1.913802e-05
# location_description_71   1.913802e-05
# location_description_65   1.924437e-05
# location_description_92   1.924437e-05
# location_description_78   1.924437e-05
# location_description_110  1.935072e-05
# location_description_40   1.977610e-05
# location_description_28   1.988245e-05
# location_description_55   2.134579e-05
# primary_type_29           2.682480e-05
# location_description_41   2.703316e-05
# location_description_21   2.769674e-05
# location_description_67   2.865386e-05
# location_description_102  2.897290e-05
# location_description_31   2.907925e-05
# location_description_107  3.314592e-05
# location_description_80   3.346495e-05
# primary_type_12           3.378399e-05
# location_description_144  3.827605e-05
# location_description_74   3.827605e-05
# location_description_97   4.361887e-05
# location_description_46   4.832362e-05
# location_description_104  4.896170e-05
# location_description_127  5.680150e-05
# location_description_77   5.741407e-05
# location_description_145  5.783946e-05
# location_description_42   6.158708e-05
# location_description_5    6.286324e-05
# location_description_13   6.360767e-05
# location_description_39   6.424574e-05
# location_description_4    6.926953e-05
# location_description_122  7.514409e-05
# location_description_9    7.644575e-05
# location_description_63   8.542985e-05
# location_description_64   8.702505e-05
# location_description_2    8.872659e-05
# location_description_101  9.077268e-05
# location_description_29   1.049933e-04
# location_description_98   1.074647e-04
# location_description_86   1.163170e-04
# primary_type_19           1.253011e-04
# location_description_32   1.295039e-04
# location_description_8    1.311757e-04
# location_description_3    1.453962e-04
# hour_13                   1.483537e-04
# location_description_106  1.493566e-04
# location_description_16   1.543803e-04
# location_description_136  1.782231e-04
# location_description_61   1.797120e-04
# primary_type_7            1.930818e-04
# location_description_30   1.992754e-04
# location_description_1    2.024913e-04
# location_description_6    2.222674e-04
# location_description_75   2.289119e-04
# location_description_87   2.302135e-04
# location_description_14   2.343610e-04
# location_description_10   2.376833e-04
# location_description_18   2.469864e-04
# location_description_121  2.473353e-04
# primary_type_26           2.679323e-04
# location_description_83   2.916688e-04
# location_description_140  3.305574e-04
# location_description_53   3.680082e-04
# location_description_26   3.787746e-04
# location_description_90   3.835857e-04
# hour_17                   4.323231e-04
# primary_type_30           4.544760e-04
# primary_type_14           4.873028e-04
# location_description_143  4.945599e-04
# location_description_137  5.263233e-04
# location_description_22   5.748596e-04
# hour_16                   5.852656e-04
# location_description_49   5.856516e-04
# location_description_131  5.865024e-04
# location_description_34   6.050533e-04
# location_description_84   6.359405e-04
# location_description_7    6.384120e-04
# primary_type_15           6.406197e-04
# location_description_56   7.128925e-04
# location_description_100  7.301076e-04
# primary_type_0            8.268443e-04
# location_description_11   8.613429e-04
# month_5                   9.705540e-04
# location_description_79   1.006548e-03
# location_description_82   1.085452e-03
# location_description_99   1.150221e-03
# location_description_44   1.158065e-03
# location_description_47   1.172979e-03
# hour_1                    1.187154e-03
# location_description_124  1.190390e-03
# primary_type_21           1.205270e-03
# location_description_72   1.296306e-03
# location_description_123  1.355647e-03
# location_description_38   1.357979e-03
# location_description_126  1.423436e-03
# location_description_114  1.467273e-03
# location_description_50   1.613145e-03
# month_4                   1.619988e-03
# month_12                  1.685522e-03
# location_description_19   1.728565e-03
# day_of_week_6             1.784474e-03
# location_description_0    1.842406e-03
# location_description_20   1.929992e-03
# month_11                  2.284693e-03
# primary_type_11           2.286460e-03
# location_description_130  2.403202e-03
# location_description_59   2.428832e-03
# location_description_36   2.661725e-03
# primary_type_4            2.717493e-03
# location_description_24   2.952769e-03
# location_description_94   3.007226e-03
# day_of_week_1             3.093093e-03
# location_description_23   3.162776e-03
# primary_type_22           3.192047e-03
# month_9                   3.199374e-03
# location_description_134  3.306331e-03
# day_of_week_2             3.556279e-03
# hour_2                    3.562655e-03
# month_1                   3.598491e-03
# primary_type_24           3.666659e-03
# primary_type_10           3.789329e-03
# primary_type_5            4.007032e-03
# location_description_45   4.046248e-03
# location_description_43   4.120239e-03
# day_of_week_3             4.459656e-03
# location_description_60   4.483742e-03
# location_description_112  4.513035e-03
# hour_15                   4.660712e-03
# month_8                   4.791191e-03
# hour_14                   4.855967e-03
# primary_type_16           5.033300e-03
# hour_3                    5.214501e-03
# day_of_week_4             5.326646e-03
# day_of_week_5             5.401633e-03
# hour_23                   5.430472e-03
# location_description_52   5.512278e-03
# month_6                   5.650483e-03
# hour_22                   5.770268e-03
# location_description_139  5.911926e-03
# hour_4                    6.014678e-03
# month_7                   6.096111e-03
# location_description_103  6.324171e-03
# month_10                  6.479790e-03
# hour_6                    6.619362e-03
# primary_type_2            6.808542e-03
# location_description_54   6.851345e-03
# hour_10                   6.876105e-03
# hour_5                    7.817532e-03
# hour_0                    7.832030e-03
# day_of_week_0             8.516283e-03
# hour_12                   8.799740e-03
# month_3                   8.970240e-03
# hour_8                    9.226966e-03
# hour_18                   9.487154e-03
# hour_21                   9.788828e-03
# hour_7                    9.976632e-03
# location_description_105  1.023150e-02
# month_2                   1.045851e-02
# hour_9                    1.098287e-02
# location_description_69   1.115386e-02
# location_description_115  1.135096e-02
# hour_11                   1.207442e-02
# primary_type_27           1.307626e-02
# primary_type_25           1.354972e-02
# location_description_113  1.407192e-02
# location_description_15   1.504114e-02
# hour_20                   1.669667e-02
# primary_type_1            1.723134e-02
# location_description_129  1.766322e-02
# hour_19                   2.179283e-02
# location_description_73   2.318666e-02
# primary_type_13           2.332766e-02
# location_description_57   2.501965e-02
# location_description_96   2.635545e-02
# primary_type_28           2.717998e-02
# primary_type_17           3.448539e-02
# primary_type_3            4.202275e-02
# location_description_17   4.281536e-02
# primary_type_8            5.719917e-02
# primary_type_9            6.115982e-02
# location_description_108  9.003519e-02
# location_description_125  9.004302e-02
# primary_type_6            9.199687e-02
# primary_type_31           1.551727e-01
# primary_type_18           2.421820e-01
# arrest                    1.000000e+00

# %%
# Keep only features with differences greater than 1e-02 between arrests and non-arrests in training model
columns_to_keep = normalized_diffs.loc[lambda x: x > 1.0e-02].keys().tolist()
print(f"Count of columns kept: {len(columns_to_keep)}")

training_df_final = training_data_2018_final[columns_to_keep]
training_df_final.head()
# Out:
# Count of columns kept: 30
#           location_description_105  month_2  hour_9  location_description_69  \
# id
# 11556487                         0        0       0                        0
# 11552699                         0        0       0                        0
# 11552724                         0        0       0                        0
# 11552731                         0        0       0                        0
# 11552715                         0        0       0                        0
#
#           location_description_115  hour_11  primary_type_27  primary_type_25  \
# id
# 11556487                         0        0                0                0
# 11552699                         0        0                0                0
# 11552724                         0        0                0                0
# 11552731                         0        0                0                0
# 11552715                         0        0                0                0
#
#           location_description_113  location_description_15  ...  \
# id                                                           ...
# 11556487                         0                        0  ...
# 11552699                         0                        0  ...
# 11552724                         0                        0  ...
# 11552731                         0                        0  ...
# 11552715                         0                        0  ...
#
#           primary_type_3  location_description_17  primary_type_8  \
# id
# 11556487               0                        0               0
# 11552699               0                        1               0
# 11552724               0                        0               0
# 11552731               0                        1               0
# 11552715               0                        0               0
#
#           primary_type_9  location_description_108  location_description_125  \
# id
# 11556487               0                         0                         0
# 11552699               0                         0                         0
# 11552724               0                         0                         0
# 11552731               0                         0                         0
# 11552715               0                         0                         0
#
#           primary_type_6  primary_type_31  primary_type_18  arrest
# id
# 11556487               1                0                0       0
# 11552699               1                0                0       0
# 11552724               0                0                0       1
# 11552731               0                0                0       0
# 11552715               0                0                0       0
#
# [5 rows x 30 columns]

# %%
# Keep only features with differences greater than 1e-02 in testing model
testing_data_final = testing_data_final[columns_to_keep]
testing_data_final.head()
# Out:
#           location_description_105  month_2  hour_9  location_description_69  \
# id
# 11938228                         0        0       0                        0
# 11940078                         0        0       0                        0
# 11938240                         0        0       0                        0
# 11937967                         0        0       0                        0
# 11938124                         0        0       0                        0
#
#           location_description_115  hour_11  primary_type_27  primary_type_25  \
# id
# 11938228                         0        0                0                0
# 11940078                         0        0                0                0
# 11938240                         0        0                0                0
# 11937967                         0        0                0                0
# 11938124                         0        0                0                0
#
#           location_description_113  location_description_15  ...  \
# id                                                           ...
# 11938228                         0                        0  ...
# 11940078                         0                        0  ...
# 11938240                         0                        0  ...
# 11937967                         0                        0  ...
# 11938124                         0                        0  ...
#
#           primary_type_3  location_description_17  primary_type_8  \
# id
# 11938228               0                        0               0
# 11940078               0                        0               0
# 11938240               0                        0               0
# 11937967               0                        0               0
# 11938124               0                        0               0
#
#           primary_type_9  location_description_108  location_description_125  \
# id
# 11938228               0                         0                         0
# 11940078               0                         0                         0
# 11938240               0                         0                         0
# 11937967               0                         0                         0
# 11938124               0                         0                         0
#
#           primary_type_6  primary_type_31  primary_type_18  arrest
# id
# 11938228               0                1                0       1
# 11940078               0                0                0       0
# 11938240               0                1                0       1
# 11937967               0                1                0       0
# 11938124               0                0                0       1
#
# [5 rows x 30 columns]

# %% [markdown]
# ## SGD Classifier

# %%
# Split training data into training and validation sets
X_SGD = training_df_final.drop("arrest", axis=1)
y_SGD = training_df_final["arrest"].values.reshape(-1,1)
print(X_SGD.shape, y_SGD.shape)
# Out:
# (260105, 29) (260105, 1)

# %%
# Split into training and validation
from sklearn.model_selection import train_test_split

X_train, X_eval, y_train, y_eval = train_test_split(X_SGD, y_SGD, test_size=0.2, random_state=42)

# %%
# Fit data 
from sklearn.linear_model import SGDClassifier

classifier = SGDClassifier()
classifier.fit(X_train, y_train)
# Out:
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
# Test model using validation dataset
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Evaluation Data Score: {classifier.score(X_eval, y_eval)}")
# Out:
# Training Data Score: 0.8591578401030353
# Evaluation Data Score: 0.8574037407969858

# %%
# Take a look at roc auc score
from sklearn.metrics import roc_auc_score

predictions = classifier.predict(X_eval)
roc_auc_score(y_eval, predictions)
# Out:
# 0.6741635062260868

# %% [markdown]
# ### Make predictions on 2019 data

# %%
# Split 2019 into X(features) and y(target)
X_SGD2019 = testing_data_final.drop("arrest", axis=1)
y_SGD2019 = testing_data_final["arrest"].values.reshape(-1,1)
print(X_SGD2019.shape, y_SGD2019.shape)
# Out:
# (256908, 29) (256908, 1)

# %%
# Use model to predict 2019 arrests
predictions_SGD2019 = classifier.predict(X_SGD2019)
predictions_SGD2019
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Take a look at roc auc score
roc_auc_score(y_SGD2019, predictions_SGD2019)
# Out:
# 0.6576947232870205

# %%
# Examine confusion matrix
pd.crosstab(y_SGD2019.ravel(), predictions_SGD2019.ravel(), rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted       0      1     All
# True
# 0          191558  10394  201952
# 1           34795  20161   54956
# All        226353  30555  256908

# %%
from sklearn.metrics import classification_report
print(classification_report(y_SGD2019, predictions_SGD2019))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.89    201952
#            1       0.66      0.37      0.47     54956
#
#     accuracy                           0.82    256908
#    macro avg       0.75      0.66      0.68    256908
# weighted avg       0.81      0.82      0.80    256908

# %% [markdown]
# ## Build SGD Classifier with Bagging

# %%
# Split training dataset into features(X) and target(y) dataframes
X = training_df_final.drop("arrest", axis=1)
y = training_df_final["arrest"].values.reshape(-1,1)
print(X.shape, y.shape)
# Out:
# (260105, 29) (260105, 1)

# %%
# Split 2019 into features(X_2019) and target(y_2019) dataframes
X_2019 = testing_data_final.drop("arrest", axis=1)
y_2019 = testing_data_final["arrest"].values.reshape(-1,1)
print(X_2019.shape, y_2019.shape)
# Out:
# (256908, 29) (256908, 1)

# %%
# Fit data
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import SGDClassifier

bagging_fit = BaggingClassifier(base_estimator=SGDClassifier(), n_estimators=50).fit(X, y.ravel())

# %%
# Score model
print(f"Training Model Score: {bagging_fit.score(X, y)}")
# Out:
# Training Model Score: 0.8588070202418254

# %%
# Use bagging to predict 2019 arrests
bagging_preds_2019 = bagging_fit.predict(X_2019)
bagging_preds_2019
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Take a look at roc auc score
from sklearn.metrics import roc_auc_score

roc_auc_score(y_2019, bagging_preds_2019)
# Out:
# 0.6576947232870205

# %%
# Examine confusion matrix
pd.crosstab(y_2019.ravel(), bagging_preds_2019.ravel(), rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted       0      1     All
# True
# 0          191558  10394  201952
# 1           34795  20161   54956
# All        226353  30555  256908

# %%
# Print classification report
from sklearn.metrics import classification_report

print(classification_report(y_2019, bagging_preds_2019))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.89    201952
#            1       0.66      0.37      0.47     54956
#
#     accuracy                           0.82    256908
#    macro avg       0.75      0.66      0.68    256908
# weighted avg       0.81      0.82      0.80    256908

# %% [markdown]
# Bagging with SGD model no different than simple SGD classifier.

# %% [markdown]
# ## Ensemble Learning: Bagging with Decision Tree and Random Forest Classifiers

# %%
# Perform bootstrap aggregation with different models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

clf1 = DecisionTreeClassifier(criterion='entropy', max_depth=1)
clf2 = RandomForestClassifier()    

bagging1 = BaggingClassifier(base_estimator=clf1, n_estimators=50).fit(X, y.ravel())
bagging2 = BaggingClassifier(base_estimator=clf2, n_estimators=50).fit(X, y.ravel())

# %%
# Show model performance
from sklearn.model_selection import cross_val_score

label = ['DecisionTree', 'RandomForest', 
         'BaggedDecisionTree', 'BaggedRandomForest']
clf_list = [clf1, clf2, bagging1, bagging2]

for clf, label in zip(clf_list, label):
    scores = cross_val_score(clf, X, y, cv=3, scoring='accuracy')
    print("Accuracy: %.2f (+/- %.2f) [%s]" %(scores.mean(), scores.std(), label))
    
    clf.fit(X, y)
    prediction = clf.predict(X_2019)
    print(pd.crosstab(y_2019.ravel(), prediction, rownames=['True'], colnames=['Predicted'], margins=True))
    print(classification_report(y_2019.ravel(), prediction))
# Out:
# Accuracy: 0.85 (+/- 0.00) [DecisionTree]
# Predicted       0      1     All
# True
# 0          201947      5  201952
# 1           40752  14204   54956
# All        242699  14209  256908
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91    201952
#            1       1.00      0.26      0.41     54956
#
#     accuracy                           0.84    256908
#    macro avg       0.92      0.63      0.66    256908
# weighted avg       0.87      0.84      0.80    256908
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Accuracy: 0.86 (+/- 0.00) [RandomForest]
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# Predicted       0      1     All
# True
# 0          194905   7047  201952
# 1           35219  19737   54956
# All        230124  26784  256908
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90    201952
#            1       0.74      0.36      0.48     54956
#
#     accuracy                           0.84    256908
#    macro avg       0.79      0.66      0.69    256908
# weighted avg       0.82      0.84      0.81    256908
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy: 0.85 (+/- 0.00) [BaggedDecisionTree]
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Predicted       0      1     All
# True
# 0          201947      5  201952
# 1           40752  14204   54956
# All        242699  14209  256908
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91    201952
#            1       1.00      0.26      0.41     54956
#
#     accuracy                           0.84    256908
#    macro avg       0.92      0.63      0.66    256908
# weighted avg       0.87      0.84      0.80    256908
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy: 0.86 (+/- 0.00) [BaggedRandomForest]
# C:\Users\Teddy\Anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Predicted       0      1     All
# True
# 0          197099   4853  201952
# 1           35486  19470   54956
# All        232585  24323  256908
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91    201952
#            1       0.80      0.35      0.49     54956
#
#     accuracy                           0.84    256908
#    macro avg       0.82      0.67      0.70    256908
# weighted avg       0.84      0.84      0.82    256908
